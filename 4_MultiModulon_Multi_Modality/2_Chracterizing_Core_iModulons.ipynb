# %% [markdown]
# # 2_Chracterizing_Core_iModulons
#
# This notebook demonstrates the second step for multi-species/strain/modality analysis using the MultiModulon package.

# %%
# Import required libraries
from multimodulon import MultiModulon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ## Step 1: Load MultiModulon object
#
# Load the saved MultiModulon object from Tutorial_1_Create_multiModulon_object.ipynb

# %%
multiModulon = MultiModulon.load_json_multimodulon("./multiModulon_Proteomics_Transcriptomics.json.gz")

# %%
multiModulon.species_palette
# Out:
# {'Proteomics': '#B24C4C', 'Transcriptomics': '#4C6AB2'}

# %% [markdown]
# ## Step 2: Visualize the core components (Available Functions)
#
# Visualize the core and unique components by view_iModulon_weights and view_core_iModulon_weights

# %%
multiModulon.view_iModulon_weights(
    species="Transcriptomics",
    component="Core_8",
    fig_size=(8, 5),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True,
    show_gene_names=True
)

# %%
multiModulon.view_iModulon_weights(
    species="Transcriptomics",
    component="Core_9",
    fig_size=(8, 5),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True,
    show_gene_names=True
)

# %% [markdown]
# ## Step 3: Compare Gene Membership for Core components
#
# Visualize the core and unique components by view_iModulon_weights and view_core_iModulon_weights

# %% [markdown]
# ### Core 8

# %%
multiModulon.view_core_iModulon_weights(
    component="Core_8",
    fig_size=(4, 2.4),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    reference_order=['Proteomics', 'Transcriptomics'],
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/thr_leu_comparison.svg"
)
# Out:
# Core_8 - Genes shared across all species (10 genes):
#   ['thrA', 'thrB', 'thrC', 'leuC', 'leuB', 'leuA', 'ilvD', 'ilvA', 'ilvC', 'lysC']

# %%
multiModulon.view_core_iModulon_weights(
    component="Core_4",
    fig_size=(4.5, 2.6),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    reference_order=['Transcriptomics', 'Proteomics'],
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/Core_4_comparison.svg"
)
# Out:
# Core_4 - Genes shared across all species (9 genes):
#   ['cstA', 'gltA', 'sucC', 'sucD', 'aldA', 'argT', 'gabD', 'gabT', 'acs']

# %%
multiModulon.view_core_iModulon_weights(
    component="Core_9",
    fig_size=(4.5, 2.6),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    reference_order=['Transcriptomics', 'Proteomics'],
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/Core_9_comparison.svg"
)
# Out:
# Core_9 - Genes shared across all species (8 genes):
#   ['ptsG', 'dhaM', 'dhaL', 'dhaK', 'mtlA', 'mtlD', 'ilvN', 'ilvB']

# %%
multiModulon.view_iModulon_weights(
    species="Transcriptomics",
    component="Unique_2",
    fig_size=(3.3, 4.5),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/transcriptomics_unique_2.svg"
)

# %%
multiModulon.view_iModulon_weights(
    species="Transcriptomics",
    component="Unique_4",
    fig_size=(6, 6),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/transcriptomics_unique_4.svg"
)

# %%
multiModulon.view_iModulon_weights(
    species="Proteomics",
    component="Unique_9",
    fig_size=(4, 3.5),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True,
    show_gene_names=True #,
    # save_path="./Output_iModulon_Figures/transcriptomics_unique_4.svg"
)

# %%
Core_1_comparison = multiModulon.compare_core_iModulon(
    component='Core_8',
    y_label='Modality',
    reference_order=['Proteomics', 'Transcriptomics'],
    fig_size=(9, 5),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_gene_names=True,
    # heatmap_palette = ['#C1C6E8', '#F0DDD2', '#FFFFFF'],
    save_path="./Output_iModulon_Figures/thr_leu_heatmap.svg"
    )

# %%
Core_1_comparison = multiModulon.compare_core_iModulon(
    component='Core_8',
    y_label='Strains',
    reference_order=['Proteomics', 'Transcriptomics'],
    fig_size=(10, 4),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    # heatmap_palette = ['#C1C6E8', '#F0DDD2', '#FFFFFF'],
    # save_path="./Output_iModulon_Figures/"
    )

# %% [markdown]
# ### Core 8

# %%
multiModulon.view_core_iModulon_weights(
    component="Core_4",
    fig_size=(4, 2.4),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    reference_order=['Proteomics', 'Transcriptomics'],
    show_COG=True,
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/carbon_comparison.svg"
)
# Out:
# Core_4 - Genes shared across all species (9 genes):
#   ['cstA', 'gltA', 'sucC', 'sucD', 'aldA', 'argT', 'gabD', 'gabT', 'acs']

# %%
Core_1_comparison = multiModulon.compare_core_iModulon(
    component='Core_4',
    y_label='Strains',
    reference_order=['Proteomics', 'Transcriptomics'],
    fig_size=(10, 4),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_gene_names=True,
    save_path="./Output_iModulon_Figures/carbon_heatmap.svg"
    # heatmap_palette = ['#C1C6E8', '#F0DDD2', '#FFFFFF'],
    # save_path="./Output_iModulon_Figures/"
    )

# %%
Core_1_comparison = multiModulon.compare_core_iModulon(
    component='Core_4',
    y_label='Strains',
    reference_order=['Proteomics', 'Transcriptomics'],
    fig_size=(10, 4),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    # heatmap_palette = ['#C1C6E8', '#F0DDD2', '#FFFFFF'],
    # save_path="./Output_iModulon_Figures/"
    )
