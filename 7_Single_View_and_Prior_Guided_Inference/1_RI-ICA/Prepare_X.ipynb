# %% [markdown]
# # Prepare minicoli removed P1K

# %%
from pathlib import Path
import sys
import os.path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import f_oneway, gaussian_kde, mannwhitneyu, pearsonr, spearmanr
import seaborn as sns
from tqdm.notebook import tqdm
from pymodulon.compare import compare_ica
from pymodulon.core import IcaData
from pymodulon.io import load_json_model, save_to_json
from pymodulon.plotting import *

sns.set_style('whitegrid')

# %% [markdown]
# ## Data preperation

# %% [markdown]
# ### Load data from Data_Basal_Expression folder

# %%
precise1k = load_json_model('p1k.json.gz')

# %%
PRECISE_1K_log_tpm = precise1k.log_tpm

# %%
PRECISE_1K_X = precise1k.X

# %%
PRECISE_1K_M = precise1k.M

# %%
PRECISE_1K_sample_table = precise1k.sample_table

# %%
PRECISE_1K_sample_table = PRECISE_1K_sample_table[PRECISE_1K_sample_table['study'] != 'Minicoli']

# %%
PRECISE_1K_sample_table.to_csv('./P1K_minicoli_removed/P1K_minicoli_removed_sample_table.csv')

# %%
PRECISE_1K_sample_table
# Out:
#                                         sample_id    study  project  \
# p1k_00001                      control__wt_glc__1  Control  control
# p1k_00002                      control__wt_glc__2  Control  control
# p1k_00003                          fur__wt_dpd__1      Fur      fur
# p1k_00004                          fur__wt_dpd__2      Fur      fur
# p1k_00005                           fur__wt_fe__1      Fur      fur
# ...                                           ...      ...      ...
# p1k_01051  DDB3__PD-006_del-rpoS_Fed-batch_15h__2     DDB3     DDB3
# p1k_01052       DDB3__PD-009_del-tnaA_Batch_6h__1     DDB3     DDB3
# p1k_01053   DDB3__PD-009_del-tnaA_Fed-batch_6h__1     DDB3     DDB3
# p1k_01054  DDB3__PD-009_del-tnaA_Fed-batch_15h__1     DDB3     DDB3
# p1k_01055  DDB3__PD-009_del-tnaA_Fed-batch_15h__2     DDB3     DDB3
#
#                                condition  rep_id  \
# p1k_00001                         wt_glc       1
# p1k_00002                         wt_glc       2
# p1k_00003                         wt_dpd       1
# p1k_00004                         wt_dpd       2
# p1k_00005                          wt_fe       1
# ...                                  ...     ...
# p1k_01051  PD-006_del-rpoS_Fed-batch_15h       2
# p1k_01052       PD-009_del-tnaA_Batch_6h       1
# p1k_01053   PD-009_del-tnaA_Fed-batch_6h       1
# p1k_01054  PD-009_del-tnaA_Fed-batch_15h       1
# p1k_01055  PD-009_del-tnaA_Fed-batch_15h       2
#
#                           Strain Description   Strain Culture Type  \
# p1k_00001       Escherichia coli K-12 MG1655   MG1655        Batch
# p1k_00002       Escherichia coli K-12 MG1655   MG1655        Batch
# p1k_00003       Escherichia coli K-12 MG1655   MG1655        Batch
# p1k_00004       Escherichia coli K-12 MG1655   MG1655        Batch
# p1k_00005       Escherichia coli K-12 MG1655   MG1655        Batch
# ...                                      ...      ...          ...
# p1k_01051  Escherichia coli BW25113 del_rpoS  BW25113    Fed-batch
# p1k_01052  Escherichia coli BW25113 del_tnaA  BW25113        Batch
# p1k_01053  Escherichia coli BW25113 del_tnaA  BW25113    Fed-batch
# p1k_01054  Escherichia coli BW25113 del_tnaA  BW25113    Fed-batch
# p1k_01055  Escherichia coli BW25113 del_tnaA  BW25113    Fed-batch
#
#           Evolved Sample Base Media  ...                   contact  \
# p1k_00001             No         M9  ...               Sangwoo Seo
# p1k_00002             No         M9  ...               Sangwoo Seo
# p1k_00003             No         M9  ...               Sangwoo Seo
# p1k_00004             No         M9  ...               Sangwoo Seo
# p1k_00005             No         M9  ...               Sangwoo Seo
# ...                  ...        ...  ...                       ...
# p1k_01051             No   Medium C  ...  sursud@biosustain.dtu.dk
# p1k_01052             No   Medium C  ...  sursud@biosustain.dtu.dk
# p1k_01053             No   Medium C  ...  sursud@biosustain.dtu.dk
# p1k_01054             No   Medium C  ...  sursud@biosustain.dtu.dk
# p1k_01055             No   Medium C  ...  sursud@biosustain.dtu.dk
#
#                    creator passed_fastqc passed_pct_reads_mapped  \
# p1k_00001      Sangwoo Seo          True                    True
# p1k_00002      Sangwoo Seo          True                    True
# p1k_00003      Sangwoo Seo          True                    True
# p1k_00004      Sangwoo Seo          True                    True
# p1k_00005      Sangwoo Seo          True                    True
# ...                    ...           ...                     ...
# p1k_01051  Suresh Sudarsan          True                    True
# p1k_01052  Suresh Sudarsan          True                    True
# p1k_01053  Suresh Sudarsan          True                    True
# p1k_01054  Suresh Sudarsan          True                    True
# p1k_01055  Suresh Sudarsan          True                    True
#
#           passed_reads_mapped_to_CDS passed_global_correlation  \
# p1k_00001                       True                      True
# p1k_00002                       True                      True
# p1k_00003                       True                      True
# p1k_00004                       True                      True
# p1k_00005                       True                      True
# ...                              ...                       ...
# p1k_01051                       True                      True
# p1k_01052                       True                      True
# p1k_01053                       True                      True
# p1k_01054                       True                      True
# p1k_01055                       True                      True
#
#                                     full_name passed_similar_replicates  \
# p1k_00001                      control:wt_glc                      True
# p1k_00002                      control:wt_glc                      True
# p1k_00003                          fur:wt_dpd                      True
# p1k_00004                          fur:wt_dpd                      True
# p1k_00005                           fur:wt_fe                      True
# ...                                       ...                       ...
# p1k_01051  DDB3:PD-006_del-rpoS_Fed-batch_15h                      True
# p1k_01052       DDB3:PD-009_del-tnaA_Batch_6h                      True
# p1k_01053   DDB3:PD-009_del-tnaA_Fed-batch_6h                      True
# p1k_01054  DDB3:PD-009_del-tnaA_Fed-batch_15h                      True
# p1k_01055  DDB3:PD-009_del-tnaA_Fed-batch_15h                      True
#
#            passed_number_replicates run_date
# p1k_00001                      True  4/17/13
# p1k_00002                      True  4/17/13
# p1k_00003                      True  10/2/13
# p1k_00004                      True  10/2/13
# p1k_00005                      True   9/5/13
# ...                             ...      ...
# p1k_01051                      True  10/1/20
# p1k_01052                     False  10/1/20
# p1k_01053                     False  10/1/20
# p1k_01054                      True  10/1/20
# p1k_01055                      True  10/1/20
#
# [981 rows x 42 columns]

# %% [markdown]
# ### Get minicoli removed X

# %%
matching_columns = [col for col in PRECISE_1K_X.columns if col in PRECISE_1K_sample_table.index]
PRECISE_1K_X_minicoli_removed = PRECISE_1K_X[matching_columns]

# %%
PRECISE_1K_X_minicoli_removed
# Out:
#        p1k_00001  p1k_00002  p1k_00003  p1k_00004  p1k_00005  p1k_00006  \
# b0002  -0.053993   0.053993   0.879043   1.089600   0.182453  -0.078873
