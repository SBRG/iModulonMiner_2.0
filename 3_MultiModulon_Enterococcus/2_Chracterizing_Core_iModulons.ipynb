# %% [markdown]
# # 2_Chracterizing_Core_iModulons
#
# This notebook demonstrates the second step for multi-species/strain/modality analysis using the MultiModulon package.

# %%
# Import required libraries
from multimodulon import MultiModulon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# ## Step 1: Load MultiModulon object
#
# Load the saved MultiModulon object from Tutorial_1_Create_multiModulon_object.ipynb

# %%
multiModulon = MultiModulon.load_json_multimodulon("./multiModulon_Enterococcus.json.gz")

# %%
multiModulon.species_palette
# Out:
# {'Enterococcus_faecalis': '#B24C4C', 'Enterococcus_faecium': '#4C6AB2'}

# %% [markdown]
# ## Step 2: Visualize the core components (Available Functions)
#
# Visualize the core and unique components by view_iModulon_weights and view_core_iModulon_weights

# %%
multiModulon['Enterococcus_faecalis'].gene_table[multiModulon['Enterococcus_faecalis'].gene_table['Preferred_name'] == 'argR']
# Out:
#             accession    start      end strand gene_name old_locus_tag  \
# WMS_00332  KB944666.1   378055   378534      -      None          None
# WMS_00333  KB944666.1   378768   379265      +      None          None
# WMS_00646  KB944666.1   683576   684031      +      None          None
# WMS_01063  KB944666.1  1103503  1103952      +      None          None
#
#                  gene_product ncbi_protein      seed_ortholog         evalue  \
# WMS_00332  arginine repressor   EOJ65864.1  1201292.DR75_2140  3.520000e-106
# WMS_00333  arginine repressor   EOJ65865.1     226185.EF_0103  6.530000e-102
# WMS_00646  arginine repressor   EOJ65684.1  1201292.DR75_2626   1.840000e-95
# WMS_01063  arginine repressor   EOJ65421.1    1201292.DR75_43   1.930000e-96
#
#            score                                         eggNOG_OGs  \
# WMS_00332  306.0  COG1438@1|root,COG1438@2|Bacteria,1V1R7@1239|F...
# WMS_00333  296.0  COG1438@1|root,COG1438@2|Bacteria,1V1R7@1239|F...
# ...

# %%
multiModulon['Enterococcus_faecalis'].gene_table[multiModulon['Enterococcus_faecalis'].gene_table['Preferred_name'] == 'iprA']
# Out:
#             accession   start     end strand gene_name old_locus_tag  \
# WMS_00337  KB944666.1  382898  383590      +      None          None
#
#                                        gene_product ncbi_protein  \
# WMS_00337  crp/FNR family transcriptional regulator   EOJ65869.1
#
#             seed_ortholog         evalue  score  \
# WMS_00337  226185.EF_0107  9.030000e-162  453.0
#
#                                                   eggNOG_OGs max_annot_lvl  \
# WMS_00337  COG0664@1|root,COG0664@2|Bacteria,1V7C0@1239|F...    2|Bacteria
#
#           COG_category                                     Description  \
# WMS_00337            K  Cyclic nucleotide-monophosphate binding domain
#
#           Preferred_name                                                GOs  \
# WMS_00337           iprA  GO:0006355,GO:0008150,GO:0009889,GO:0010468,GO...
#
#           EC    KEGG_ko KEGG_Pathway KEGG_Module KEGG_Reaction KEGG_rclass  \
# ...

# %%
multiModulon.view_iModulon_weights(
    component='Core_2',
    species = 'Enterococcus_faecium',
    fig_size=(4, 4),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True
)

# %%
multiModulon.view_iModulon_weights(
    component='Core_2',
    species = 'Enterococcus_faecalis',
    fig_size=(4, 4),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_COG=True
)

# %%
multiModulon.view_core_iModulon_weights(
    component='Core_2',
    fig_size=(5, 3),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    reference_order=['Enterococcus_faecium', 'Enterococcus_faecalis'],
    show_COG=True,
    show_gene_names=True,
    save_path='./Paper_Figures/Enterococcus_Core_2_weights.svg'
)

# %%
Core_5_comparison = multiModulon.compare_core_iModulon(
    component='Core_2',
    y_label='Species',
    reference_order=['Enterococcus_faecium','Enterococcus_faecalis'],
    fig_size=(20, 4),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf",
    show_gene_names = True
    )

# %%
Core_5_comparison = multiModulon.compare_core_iModulon(
    component='Core_2',
    y_label='Species',
    reference_order=['Enterococcus_faecium','Enterococcus_faecalis'],
    fig_size=(20, 4),
    font_path="/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    )

# %%
multiModulon.show_gene_iModulon_correlation(
    gene='E6A31_08405',
    component='Core_2',
    fig_size=(4, 3),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    )

# %%
multiModulon.show_gene_iModulon_correlation(
    gene='E6A31_05460',
    component='Core_2',
    fig_size=(4, 3),
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    )
